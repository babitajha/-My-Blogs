# %%
#pip install PyPDF2
# Out:
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61255 sha256=b4a21fee39f4700f364e9ccc87ac7287435e64d941d5cd4e6126d17b4cfd0615
#   Stored in directory: c:\users\babita\appdata\local\pip\cache\wheels\80\1a\24\648467ade3a77ed20f35cfd2badd32134e96dd25ca811e64b3
# Successfully built PyPDF2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyPDF2 
# open file as per your locatio or file name
pdfFileObj = open('28-55-1-SM.pdf', 'rb') 
  
# creating a pdf reader object for pdf file reading
pdfReader = PyPDF2.PdfFileReader(pdfFileObj) 
  
# printing number of pages in pdf file 
print(pdfReader.numPages) 
  
# creating a page object 
pageObj = pdfReader.getPage(0) 
  
# extracting text from page 
print(pageObj.extractText()) 
  
# closing the pdf file object 
pdfFileObj.close()
# Out:
# 8
#   UNSTRUCTURED D
# ATA
#  PRACTICES IN POLAR INSTITUTIONS
# AND NETWORKS: A CASE STUDY WITH THE
# ARCTIC OPTIONS
#  PROJECT
#   Paul
#  Arthur
#  Berkman
# 1,2 *
#   1 Bren School of Environmental Science and Management / Marine Science Institute, University of California,
# Santa Barb
# ara, CA 93106, USA
#  *Email:
# berkman@bren.ucsb.edu
#  2 DigIn
#  (Digital Integration Technology Limited), 6 Caxton House, Broad Street, Great Cambourne, Cambridge,
# CB23 6JN, UK
#  Email: paul.berkman@digin.co
#   ABSTRACT
#   Arctic Options: Holistic Integration for Ar
# ctic Coastal
# -Marine Sustainability
#  is a new three
# -year research
# project to assess future infrastructure associated with the Arctic Ocean regarding: (1) natural and living
# environment; (2) built environment; (3) natural resource development; and (4) governa
# nce.
#  For the assessments,
# Arctic Options will generate objective relational schema from numeric data as well as textual data.
#  This paper
# ...

# %% [markdown]
# Reading file using tabula based on the page no by default tabula is giving page no1 output if we want to extract multiple_tables then set multiple_tables = True, and stream is used for the line separater

# %%
import tabula

# %%
import tabula
df = tabula.read_pdf("28-55-1-SM.pdf", pages = "all" , multiple_tables=True)
df[0]#reading table based on the index
# Out:
#                         Unnamed: 0   Interconnected Core Elements  \
# 0                              NaN   Solution Suites for  Digital
# 1                              NaN             Discovery      NaN
# 2         Attributes and Functions                   NaN      NaN
# 3                    (see Table 2)   Content and Context      NaN
# 4                              NaN      Search Databases      NaN
# 5                              NaN  Engines Spreadsheets      NaN
# 6             Language Independent                   N Y      NaN
# 7            File-type Independent                   Y N      NaN
# 8                Scale Independent                   Y N      NaN
# 9       Classification Independent                   N Y      NaN
# 10             Ranking Independent                   N Y      NaN
# 11              Markup Independent                   Y Y      NaN
# 12            Metadata Independent                   N Y      NaN
# ...

# %% [markdown]
# converting the pdf file into csv and we can convert into different file format also like json etc

# %%
df = tabula.read_pdf("28-55-1-SM.pdf", pages = "all" , multiple_tables=True)
tabula.convert_into("28-55-1-SM.pdf", "28-55-1-SM2.csv", output_format="csv",pages = "all ")

# %%
#pip install python-docx
# Out:
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.10-py3-none-any.whl size=188012 sha256=8a998c9e13d1724190b20d4fd838d2587f57f99bb5abf2dc417b4b4fd6527cf8
#   Stored in directory: c:\users\babita\appdata\local\pip\cache\wheels\75\c6\69\05491f32dc052cd70476b65f5bf7082a9b274045f6b001b821
# Successfully built python-docx
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install docx2txt
# Out:
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3898 sha256=49539bc3a9268e0b1311be54cee1d9bbbc359bcbce37fd0ecd2e63c2d26646c1
#   Stored in directory: c:\users\babita\appdata\local\pip\cache\wheels\b7\20\b2\473e3aea9a0c0d3e7b2f7bd81d06d0794fec12752733d1f3a8
# Successfully built docx2txt
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from docx import Document
document = Document('gfsarpt04.docx')
for table in document.tables:
    for row in table.rows:       
        for cell in row.cells:        
            print (cell.text)
# Out:
# State/Outlying Area
# Number of s4tudents expelled in 2001-2002
# Public elementary/secondary enrollment*
# Expelled students per 1,000 of enrollment
# Alabama
# 138
# 726,367
# 0.190
# Alaska
# 55
# 134,023
# 0.410
# Arizona
# 124
# 903,518
# 0.137
# Arkansas
# 80
# 448,246
# 0.178
# California
# 104
# 6,247,889
# 0.017
# Colorado
# 31
# 742,065
# 0.042
# Connecticut
# 8
# 570,145
# 0.014
# Delaware
# 3
# 115,486
# 0.026
# District of Columbia
# 3
# 68,449
# 0.044
# Florida
# 51
# 2,500,161
# 0.020
# Georgia
# 119
# 1,470,634
# 0.081
# Hawaii
# 7
# 184,546
# 0.038
# Idaho
# 21
# 246,000
# 0.085
# Illinois
# 53
# 2,068,182
# 0.026
# Indiana
# 41
# 994,545
# 0.041
# Iowa
# 9
# 491,169
# 0.018
# Kansas
# 32
# 468,140
# 0.068
# Kentucky
# 46
# 630,461
# 0.073
# Louisiana
# 75
# 731,474
# 0.103
# Maine
# 2
# 211,461
# 0.009
# Maryland
# 21
# 860,890
# 0.024
# Massachusetts
# 89
# 979,593
# 0.091
# Michigan
# 46
# 1,733,900
# 0.027
# Minnesota
# 23
# 845,700
# 0.027
# Mississippi
# 67
# ...

# %%
import pandas as pd

# %%
from docx.api import Document
import pandas as pd
# Load the first table from your document. In your example file,
# there is only one table, so I just grab the first one.
document = Document('gfsarpt04.docx')
table = document.tables[0] 
data = [] 
keys = {} 
 
for i, row in enumerate(table.rows): 
    text = (cell.text for cell in row.cells) 
    if i == 0: 
        keys = tuple(text) 
        continue 
 
    row_data = dict(zip(keys, text)) 
    data.append(row_data) 
    print(data)
df = pd.DataFrame(data)
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
import io
import csv
from docx import Document

def read_docx_tables(filename, tab_id=None, **kwargs):
   
    def read_docx_tab(tab, **kwargs):
        vf = io.StringIO()
        writer = csv.writer(vf)
        for row in tab.rows:
            writer.writerow(cell.text for cell in row.cells)
        vf.seek(0)
        return pd.read_csv(vf, **kwargs)

    doc = Document("gfsarpt04.docx")
    if tab_id is None:
        return [read_docx_tab(tab, **kwargs) for tab in doc.tables]
    else:
        try:
            return read_docx_tab(doc.tables[tab_id], **kwargs)
        except IndexError:
            print('Error: specified [tab_id]: {}  does not exist.'.format(tab_id))
            raise

# %%
dfs = read_docx_tables("doc")
dfs[1]
# Out:
#    State/Outlying Area Number of s4tudents expelled in 2001-2002  \
# 0                  138                                   726,367
# 1              134,023                                     0.410
# 2                0.137                                  Arkansas
# 3           California                                       104
# 4                   31                                   742,065
# 5              570,145                                     0.014
# 6                0.026                      District of Columbia
# 7              Florida                                        51
# 8                  119                                 1,470,634
# 9              184,546                                     0.038
# 10               0.085                                  Illinois
# 11             Indiana                                        41
# 12                   9                                   491,169
# ...
